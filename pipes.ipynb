# %%
import pandas as pd
import numpy as np
import re
import os
import multiprocessing as mp

# %%
# cols = pd.read_table('../prepr_new/2017062100490000_2017-06-21_20.29.17.txt',  index_col=False, skiprows=1, nrows=1).columns
directory1 = '../prepr_new/'
# directory2 = '../data_rewr/'

# %%
def process(f):
    cc = pd.read_table(os.path.join(directory1, f),  index_col=False,skiprows=1).columns
#     if len(cc)==560:
#         directory2 = '../data560/'
#     if len(cc)==641:
#         directory2 = '../data641/'
    if len(cc)==668:
        directory2 = '../data668/'
    if len(cc)==686: 
        directory2 = '../data686/'
    else:
        pass
        
    df = pd.read_table(os.path.join(directory1, f),  index_col=False,skiprows=1,  usecols=cc[:-1])
    df= df.iloc[::20, :]

#         pattern = '.+\.'
#         pattern = 'ACC.'

#         df.columns = [re.sub(pattern, '', col) for col in cols[:-1]]
#         df = df.T.drop_duplicates().T
    df.to_csv(os.path.join(directory2, f), sep='\t', index=False, header=False)

# %%
file_list = []
for filename in os.listdir(directory1):
    if filename.endswith(".txt"): 
        file_list.append(filename)

# %%
if __name__ == '__main__':
    p = mp.Pool(20)
    p.map(process, file_list)
#     p.close()
#     p.join()

# %%
a = pd.read_table('2017062100560000.txt',skiprows=1)

# %%
a.columns.tolist()
# Out:
# ['time',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs1',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs2',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs3',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs4',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs5',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs1',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs2',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs3',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs4',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs5',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc1PosRef',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc2PosRef',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc3PosRef',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc4PosRef',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc5PosRef',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[1]',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[2]',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[3]',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[4]',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[5]',
# ...

# %%
a.columns.tolist()
# Out:
# ['time',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs1',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs2',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs3',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs4',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs5',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs1',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs2',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs3',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs4',
#  'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs5',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc1PosRef',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc2PosRef',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc3PosRef',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc4PosRef',
#  'ACC.PRC.GlobVar.PrcLocRtData.Prc5PosRef',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[1]',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[2]',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[3]',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[4]',
#  'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[5]',
# ...

# %%
#641
cols641 = pd.read_table('../data/20170213_1_54.txt',index_col=False, header=1).columns
data = pd.read_table('../data_rewr/all_641.txt',index_col=False, names=cols641[:-1])

# %%
data.loc[(data['ACC.GSF.GlobVar.AccTrkMap.PosHeadCol[1]']>139)][['time','ACC.GSF.GlobVar.AccTrkMap.PosHeadCol[1]', 'ACC.GFC.GlobVar.AccPyr.Pyr[5].Tmp']]
# Out:
#                              time  ACC.GSF.GlobVar.AccTrkMap.PosHeadCol[1]  \
# 7      13.02.2017 08:48:26.060000                                  139.245
# 8      13.02.2017 08:48:26.660000                                  140.389
# 9      13.02.2017 08:48:27.260000                                  141.466
# 10     13.02.2017 08:48:27.860000                                  142.283
# 11     13.02.2017 08:48:28.460000                                  143.278
# 12     13.02.2017 08:48:29.060000                                  144.299
# 13     13.02.2017 08:48:29.660000                                  145.365
# 14     13.02.2017 08:48:30.260000                                  146.460
# 15     13.02.2017 08:48:30.860000                                  147.577
# 16     13.02.2017 08:48:31.460000                                  148.715
# 17     13.02.2017 08:48:32.060000                                  149.439
# ...

# %%
data.loc[(data['ACC.GSF.GlobVar.AccTrkMap.PosHeadCol[1]']>205)&(data['ACC.GSF.GlobVar.AccTrkMap.PosHeadCol[1]']<208)][['time','ACC.GSF.GlobVar.AccTrkMap.PosHeadCol[1]', 'ACC.GFC.GlobVar.AccPyr.Pyr[7].Tmp']]
# Out:
#                              time  ACC.GSF.GlobVar.AccTrkMap.PosHeadCol[1]  \
# 65     13.02.2017 08:49:00.860000                                  205.393
# 66     13.02.2017 08:49:01.460000                                  206.562
# 67     13.02.2017 08:49:02.060000                                  207.755
# 326    13.02.2017 09:02:59.750000                                  205.482
# 327    13.02.2017 09:03:00.350000                                  206.623
# 328    13.02.2017 09:03:00.950000                                  207.761
# 458    13.02.2017 09:06:48.440000                                  205.938
# 459    13.02.2017 09:06:49.040000                                  207.086
# 591    13.02.2017 09:17:49.880000                                  206.196
# 592    13.02.2017 09:17:50.480000                                  207.393
# 721    13.02.2017 09:21:51.020000                                  206.061
# ...

# %%
pattern1 = 'ACC.'
pattern2 = '[A-Za-z]+\.[A-Za-z]+\.'
pattern3 = "For ITC - Don't remove_GFC.AppHmi.GfcHmi.A_Gfc2Hmi_V22a."
parse_cols = df.columns
# df.columns = [re.sub(pattern1, '', col) for col in parse_cols]
df.columns = [col.replace(pattern1, '').replace(pattern2, '').replace(pattern3, '') for col in parse_cols]

# df = df.T.drop_duplicates().T

# %%
a = ['ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[1]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[2]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[3]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[4]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[5]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[6]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[7]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[8]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[9]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[1]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[2]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[3]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[4]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[5]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[6]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[7]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[8]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[9]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[1]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[2]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[3]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[4]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[5]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[6]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[7]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[8]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[9]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[1]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[2]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[3]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[4]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[5]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[6]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[7]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[8]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[9]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[1]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[2]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[3]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[4]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[5]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[6]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[7]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[8]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[9]', 'Unnamed: 684']

c = ['ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs1', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs2', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs3', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs4', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActDs5', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs1', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs2', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs3', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs4', 'ACC.PRC.GlobVar.PrcLocRtData.PrcPosActOs5', 'ACC.PRC.GlobVar.PrcLocRtData.Prc1PosRef', 'ACC.PRC.GlobVar.PrcLocRtData.Prc2PosRef', 'ACC.PRC.GlobVar.PrcLocRtData.Prc3PosRef', 'ACC.PRC.GlobVar.PrcLocRtData.Prc4PosRef', 'ACC.PRC.GlobVar.PrcLocRtData.Prc5PosRef', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[1]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[2]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[3]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[4]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[5]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[6]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[7]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[8]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Ds[9]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[1]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[2]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[3]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[4]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[5]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[6]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[7]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[8]', 'ACC.EMC.GlobVar.EmcLocRtData.Mot_Pos_Act_Os[9]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[1]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[2]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[3]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[4]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[5]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[6]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[7]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[8]', 'ACC.EMC.GlobVar.EmcLocRtData.Car_Pos_Ref[9]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[1]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[2]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[3]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[4]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[5]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[6]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[7]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[8]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Act[9]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[1]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[2]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[3]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[4]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[5]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[6]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[7]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[8]', 'ACC.THL.ResGlobVar.ThlLocRtData.Mot_Pos_Ref[9]', 'ACC.THC.GlobVar.AccCtrlOutput_Cen.SpecFlwAct[33]', 'ACC.THC.GlobVar.AccCtrlOutput_Cen.FlwCtrlAdj[33]', 'ACC.THC.GlobVar.AccCtrlOutput_Cen.SpecFlwAct[34]', 'ACC.THC.GlobVar.AccCtrlOutput_Cen.FlwCtrlAdj[34]', 'ACC.THC.GlobVar.AccCtrlOutput_Cen.SpecFlwAct[35]', 'ACC.THC.GlobVar.AccCtrlOutput_Cen.FlwCtrlAdj[35]', 'ACC.THC.GlobVar.AccCtrlOutput_Cen.SpecFlwAct[36]', 'ACC.THC.GlobVar.AccCtrlOutput_Cen.FlwCtrlAdj[36]', 'ACC.THC.GlobVar.AccCtrlOutput_Out.SpecFlwAct[33]', 'ACC.THC.GlobVar.AccCtrlOutput_Out.FlwCtrlAdj[33]', 'ACC.THC.GlobVar.AccCtrlOutput_Out.SpecFlwAct[34]', 'ACC.THC.GlobVar.AccCtrlOutput_Out.FlwCtrlAdj[34]', 'ACC.THC.GlobVar.AccCtrlOutput_Out.SpecFlwAct[35]', 'ACC.THC.GlobVar.AccCtrlOutput_Out.FlwCtrlAdj[35]', 'ACC.THC.GlobVar.AccCtrlOutput_Out.SpecFlwAct[36]', 'ACC.THC.GlobVar.AccCtrlOutput_Out.FlwCtrlAdj[36]', 'ACC.THC.GlobVar.AccCtrlInput_Cen.FlwCtrlAdjFbk[33]', 'ACC.THC.GlobVar.AccCtrlInput_Cen.FlwCtrlAdjFbk[34]', 'ACC.THC.GlobVar.AccCtrlInput_Cen.FlwCtrlAdjFbk[35]', 'ACC.THC.GlobVar.AccCtrlInput_Cen.FlwCtrlAdjFbk[36]', 'ACC.THC.GlobVar.AccCtrlInput_Out.FlwCtrlAdjFbk[33]', 'ACC.THC.GlobVar.AccCtrlInput_Out.FlwCtrlAdjFbk[34]', 'ACC.THC.GlobVar.AccCtrlInput_Out.FlwCtrlAdjFbk[35]', 'ACC.THC.GlobVar.AccCtrlInput_Out.FlwCtrlAdjFbk[36]', 'ACC.THC.GlobVar.AccCtrlInput_Cen.SpecFlwRef[33]', 'ACC.THC.GlobVar.AccCtrlInput_Cen.SpecFlwRef[34]', 'ACC.THC.GlobVar.AccCtrlInput_Cen.SpecFlwRef[35]', 'ACC.THC.GlobVar.AccCtrlInput_Cen.SpecFlwRef[36]', 'ACC.THC.GlobVar.AccCtrlInput_Out.SpecFlwRef[33]', 'ACC.THC.GlobVar.AccCtrlInput_Out.SpecFlwRef[34]', 'ACC.THC.GlobVar.AccCtrlInput_Out.SpecFlwRef[35]', 'ACC.THC.GlobVar.AccCtrlInput_Out.SpecFlwRef[36]', 'ACC.THC._ThcRtData.ThcRtData.WatAbsFlwSum', 'ACC.BHC.GlobVar.AccCtrlOutput_Cen.SpecFlwAct[33]', 'ACC.BHC.GlobVar.AccCtrlOutput_Cen.FlwCtrlAdj[33]', 'ACC.BHC.GlobVar.AccCtrlOutput_Cen.SpecFlwAct[34]', 'ACC.BHC.GlobVar.AccCtrlOutput_Cen.FlwCtrlAdj[34]', 'ACC.BHC.GlobVar.AccCtrlOutput_Cen.SpecFlwAct[35]', 'ACC.BHC.GlobVar.AccCtrlOutput_Cen.FlwCtrlAdj[35]', 'ACC.BHC.GlobVar.AccCtrlOutput_Cen.SpecFlwAct[36]', 'ACC.BHC.GlobVar.AccCtrlOutput_Cen.FlwCtrlAdj[36]', 'ACC.BHC.GlobVar.AccCtrlOutput_Out.SpecFlwAct[33]', 'ACC.BHC.GlobVar.AccCtrlOutput_Out.FlwCtrlAdj[33]', 'ACC.BHC.GlobVar.AccCtrlOutput_Out.SpecFlwAct[34]', 'ACC.BHC.GlobVar.AccCtrlOutput_Out.FlwCtrlAdj[34]', 'ACC.BHC.GlobVar.AccCtrlOutput_Out.SpecFlwAct[35]', 'ACC.BHC.GlobVar.AccCtrlOutput_Out.FlwCtrlAdj[35]', 'ACC.BHC.GlobVar.AccCtrlOutput_Out.SpecFlwAct[36]', 'ACC.BHC.GlobVar.AccCtrlOutput_Out.FlwCtrlAdj[36]', 'ACC.BHC.GlobVar.AccCtrlInput_Cen.FlwCtrlAdjFbk[33]', 'ACC.BHC.GlobVar.AccCtrlInput_Cen.FlwCtrlAdjFbk[34]', 'ACC.BHC.GlobVar.AccCtrlInput_Cen.FlwCtrlAdjFbk[35]', 'ACC.BHC.GlobVar.AccCtrlInput_Cen.FlwCtrlAdjFbk[36]', 'ACC.BHC.GlobVar.AccCtrlInput_Out.FlwCtrlAdjFbk[33]', 'ACC.BHC.GlobVar.AccCtrlInput_Out.FlwCtrlAdjFbk[34]', 'ACC.BHC.GlobVar.AccCtrlInput_Out.FlwCtrlAdjFbk[35]', 'ACC.BHC.GlobVar.AccCtrlInput_Out.FlwCtrlAdjFbk[36]', 'ACC.BHC.GlobVar.AccCtrlInput_Cen.SpecFlwRef[33]', 'ACC.BHC.GlobVar.AccCtrlInput_Cen.SpecFlwRef[34]', 'ACC.BHC.GlobVar.AccCtrlInput_Cen.SpecFlwRef[35]', 'ACC.BHC.GlobVar.AccCtrlInput_Cen.SpecFlwRef[36]', 'ACC.BHC.GlobVar.AccCtrlInput_Out.SpecFlwRef[33]', 'ACC.BHC.GlobVar.AccCtrlInput_Out.SpecFlwRef[34]', 'ACC.BHC.GlobVar.AccCtrlInput_Out.SpecFlwRef[35]', 'ACC.BHC.GlobVar.AccCtrlInput_Out.SpecFlwRef[36]', 'ACC.BHC._BhcRtData.BhcRtData.WatAbsFlwSum', 'Unnamed: 684']
